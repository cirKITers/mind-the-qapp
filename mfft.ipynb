# %%
import pennylane as qml
from pennylane.fourier import coefficients, _
from functools import partial

from itertools import product
from time import time
import plotly.express as px
import numpy as np

# %%
rng = np.random.default_rng(1111)

n_qubits = 2
n_layers = 1
max_freq = n_qubits * n_layers

dev = qml.device("default.qubit", wires=n_qubits)

weights = rng.random(size=(n_layers*n_qubits*2))
x = 0.1

# %%
@qml.qnode(dev)
def circuit_with_weights(w):
    w_idx = 0
    for l in range(n_layers):
        for q in range(n_qubits):
            qml.RY(w[w_idx], wires=q)
            w_idx += 1
            qml.RZ(w[w_idx], wires=q)
            w_idx += 1

        if n_qubits > 1:
            for q in range(n_qubits):
                qml.CNOT(wires=[q, (q + 1) % n_qubits])

    return qml.expval(qml.PauliZ(0))

# %%
def fourier_series(coeffs, frequencies, x):
    fs_sum = 0
    for c, omega in zip(coeffs, frequencies):
        # print(f"c_{omega} = (c_{-omega})* = {c}")
        fs_sum += c * np.exp(1j * x * omega)
        if omega > 0:
            fs_sum += np.conjugate(c) * np.exp(1j * x * -omega)
    return fs_sum

# %%
def recursive_fourier_series(coeffs, degree, xvec):
    n_ranges = [np.arange(-d, d + 1) for d in np.array((degree,)*len(xvec))]
    nvecs = product(*(n_ranges))

    mfs_sum = 0
    for c, nvec in zip(coeffs.flatten(), nvecs):
        mfs_prod = 1
        for x, n in zip(xvec, nvec):
            mfs_prod *= c * np.exp(1j * x * n)
            if n > 0:
                mfs_prod += np.conjugate(c) * np.exp(1j * x * -n)
        mfs_sum += mfs_prod

    return mfs_sum

# %%
def coefficients(f, degree):
    if isinstance(max_freq, int):
        max_freq = [max_freq]

    degree = np.array(max_freq)

    # number of integer values for the indices n_i = -degree_i,...,0,...,degree_i
    k = 2 * degree + 1

    # create generator for indices nvec = (n1, ..., nN), ranging from (-d1,...,-dN) to (d1,...,dN)
    n_ranges = [np.arange(d + 1) for d in degree]
    nvecs = product(*(n_ranges))

    # here we will collect the discretized values of function f
    f_discrete = np.zeros(shape=tuple(k))

    spacing = 2 * np.pi / k

    for nvec in nvecs:
        sampling_point = spacing * np.array(nvec)
        # fill discretized function array with value of f at inpts
        f_discrete[nvec] = f(sampling_point)

    coeffs = np.fft.fftn(f_discrete) / k

    return coeffs

# %%
# freqs = np.concatenate([np.arange(max_freq+1), np.arange(-max_freq, 0)])
coeffs = coefficients(circuit_with_weights, len(weights), max_freq)

print(coeffs.shape)
print(coeffs)
start = time()
res_fft = recursive_fourier_series(coeffs, max_freq, weights)
end = time()
print(f"Calculation using FFT took {end-start}")
print(f"Result using FFT: {np.real(res_fft)}")

start = time()
res_pl = circuit_with_weights(weights)
end = time()
print(f"Calculation using pennylane took {end-start}")
print(f"Result using Pennylane: {res_pl}")
# Out:
# (5, 5, 5, 5)
# [[[[ 3.97903932e-17+0.j  2.13162821e-18+0.j -1.42108547e-17+0.j
#     -1.42108547e-17+0.j  2.13162821e-18+0.j]
#    [ 5.00000000e-01+0.j  5.25132043e-18+0.j  1.54877836e-18+0.j
#      1.54877836e-18+0.j  5.25132043e-18+0.j]
#    [-1.75655824e-18+0.j -1.02388001e-18+0.j -2.50939615e-18+0.j
#     -9.78525787e-19+0.j  4.11765553e-18+0.j]]
#
#   [[ 9.86840392e-18+0.j -7.03568597e-18+0.j -2.49713982e-19+0.j
#      3.28931920e-18+0.j  3.21156911e-18+0.j]
#    [-1.75655824e-18+0.j  4.11765553e-18+0.j -9.78525787e-19+0.j
#     -2.50939615e-18+0.j -1.02388001e-18+0.j]
#    [ 8.59058243e-18+0.j  7.11460451e-18+0.j  1.64465960e-18+0.j
#     -2.42116253e-18+0.j -2.12856916e-18+0.j]
#    [ 8.59058243e-18+0.j  7.11460451e-18+0.j  1.64465960e-18+0.j
#     -2.42116253e-18+0.j -2.12856916e-18+0.j]
#    [-1.75655824e-18+0.j  4.11765553e-18+0.j -9.78525787e-19+0.j
#     -2.50939615e-18+0.j -1.02388001e-18+0.j]]
#
#   [[ 1.08561270e-18+0.j  6.55461231e-18+0.j -6.11664120e-18+0.j
#      1.80533259e-18+0.j  5.11217859e-19+0.j]
#    [ 3.51311649e-18+0.j  2.27439320e-18+0.j  3.81268803e-18+0.j
#     -1.28880401e-18+0.j  6.31847346e-19+0.j]
#    [-2.67443456e-18+0.j -5.70895221e-18+0.j  2.83416224e-19+0.j
#     -6.51645941e-19+0.j -2.50656025e-18+0.j]
#    [-2.67443456e-18+0.j -5.70895221e-18+0.j  2.83416224e-19+0.j
#     -6.51645941e-19+0.j -2.50656025e-18+0.j]
#    [ 3.51311649e-18+0.j  2.27439320e-18+0.j  3.81268803e-18+0.j
#     -1.28880401e-18+0.j  6.31847346e-19+0.j]]]
#
#
#  [[[-1.31252420e-17+0.j  4.02388804e-18+0.j -7.29619187e-19+0.j
#     -7.29619187e-19+0.j  4.02388804e-18+0.j]
#    [ 0.00000000e+00+0.j  5.06990355e-19+0.j  1.04885141e-18+0.j
#      1.04885141e-18+0.j  5.06990355e-19+0.j]
#    [ 8.96565239e-18+0.j  3.01980663e-18+0.j -2.90448786e-18+0.j
#     -2.90448786e-18+0.j  3.01980663e-18+0.j]
#    [ 8.96565239e-18+0.j  3.01980663e-18+0.j -2.90448786e-18+0.j
#     -2.90448786e-18+0.j  3.01980663e-18+0.j]
#    [ 0.00000000e+00+0.j  5.06990355e-19+0.j  1.04885141e-18+0.j
#      1.04885141e-18+0.j  5.06990355e-19+0.j]]
#
#   [[ 1.08561270e-18+0.j  5.11217859e-19+0.j  1.80533259e-18+0.j
#     -6.11664120e-18+0.j  6.55461231e-18+0.j]
#    [ 3.51311649e-18+0.j  6.31847346e-19+0.j -1.28880401e-18+0.j
#      3.81268803e-18+0.j  2.27439320e-18+0.j]
#    [-2.67443456e-18+0.j -2.50656025e-18+0.j -6.51645941e-19+0.j
#      2.83416224e-19+0.j -5.70895221e-18+0.j]
#    [-2.67443456e-18+0.j -2.50656025e-18+0.j -6.51645941e-19+0.j
#      2.83416224e-19+0.j -5.70895221e-18+0.j]
#    [ 3.51311649e-18+0.j  6.31847346e-19+0.j -1.28880401e-18+0.j
#      3.81268803e-18+0.j  2.27439320e-18+0.j]]
#
#   [[ 9.86840392e-18+0.j  3.21156911e-18+0.j  3.28931920e-18+0.j
#     -2.49713982e-19+0.j -7.03568597e-18+0.j]
#    [-1.75655824e-18+0.j -1.02388001e-18+0.j -2.50939615e-18+0.j
#     -9.78525787e-19+0.j  4.11765553e-18+0.j]
#    [ 8.59058243e-18+0.j -2.12856916e-18+0.j -2.42116253e-18+0.j
#      1.64465960e-18+0.j  7.11460451e-18+0.j]
#    [ 8.59058243e-18+0.j -2.12856916e-18+0.j -2.42116253e-18+0.j
#      1.64465960e-18+0.j  7.11460451e-18+0.j]
#    [-1.75655824e-18+0.j -1.02388001e-18+0.j -2.50939615e-18+0.j
#     -9.78525787e-19+0.j  4.11765553e-18+0.j]]
#
#   [[ 9.86840392e-18+0.j -7.03568597e-18+0.j -2.49713982e-19+0.j
#      3.28931920e-18+0.j  3.21156911e-18+0.j]
#    [-1.75655824e-18+0.j  4.11765553e-18+0.j -9.78525787e-19+0.j
#     -2.50939615e-18+0.j -1.02388001e-18+0.j]
#    [ 8.59058243e-18+0.j  7.11460451e-18+0.j  1.64465960e-18+0.j
#     -2.42116253e-18+0.j -2.12856916e-18+0.j]
#    [ 8.59058243e-18+0.j  7.11460451e-18+0.j  1.64465960e-18+0.j
#     -2.42116253e-18+0.j -2.12856916e-18+0.j]
#    [-1.75655824e-18+0.j  4.11765553e-18+0.j -9.78525787e-19+0.j
#     -2.50939615e-18+0.j -1.02388001e-18+0.j]]
#
#   [[ 1.08561270e-18+0.j  6.55461231e-18+0.j -6.11664120e-18+0.j
#      1.80533259e-18+0.j  5.11217859e-19+0.j]
#    [ 3.51311649e-18+0.j  2.27439320e-18+0.j  3.81268803e-18+0.j
#     -1.28880401e-18+0.j  6.31847346e-19+0.j]
#    [-2.67443456e-18+0.j -5.70895221e-18+0.j  2.83416224e-19+0.j
#     -6.51645941e-19+0.j -2.50656025e-18+0.j]
#    [-2.67443456e-18+0.j -5.70895221e-18+0.j  2.83416224e-19+0.j
#     -6.51645941e-19+0.j -2.50656025e-18+0.j]
#    [ 3.51311649e-18+0.j  2.27439320e-18+0.j  3.81268803e-18+0.j
#     -1.28880401e-18+0.j  6.31847346e-19+0.j]]]
#
#
#  [[[-6.76995458e-18+0.j -1.53698846e-18+0.j  3.83824366e-18+0.j
#      3.83824366e-18+0.j -1.53698846e-18+0.j]
#    [ 2.27373675e-17+0.j  3.01980663e-18+0.j -5.08911792e-18+0.j
#     -5.08911792e-18+0.j  3.01980663e-18+0.j]
#    [ 7.37683053e-18+0.j -6.84626039e-19+0.j  9.49550039e-19+0.j
#      9.49550039e-19+0.j -6.84626039e-19+0.j]
#    [ 7.37683053e-18+0.j -6.84626039e-19+0.j  9.49550039e-19+0.j
#      9.49550039e-19+0.j -6.84626039e-19+0.j]
#    [ 2.27373675e-17+0.j  3.01980663e-18+0.j -5.08911792e-18+0.j
#     -5.08911792e-18+0.j  3.01980663e-18+0.j]]
#
#   [[-1.55527458e-17+0.j -6.69643200e-18+0.j  4.93609256e-18+0.j
#      4.45880010e-18+0.j  1.28349329e-18+0.j]
#    [-9.19745838e-18+0.j -1.52592071e-18+0.j  3.53822580e-18+0.j
#     -5.41276824e-19+0.j -3.81538601e-18+0.j]
#    [ 6.46473137e-19+0.j -1.40317747e-18+0.j  7.27505434e-19+0.j
#     -1.23638639e-18+0.j -2.69512577e-19+0.j]
#    [ 6.46473137e-19+0.j -1.40317747e-18+0.j  7.27505434e-19+0.j
#     -1.23638639e-18+0.j -2.69512577e-19+0.j]
#    [-9.19745838e-18+0.j -1.52592071e-18+0.j  3.53822580e-18+0.j
#     -5.41276824e-19+0.j -3.81538601e-18+0.j]]
#
#   [[ 7.44090013e-18+0.j -2.41409913e-18+0.j -6.36896792e-18+0.j
#      8.01574128e-18+0.j -3.23064556e-18+0.j]
#    [ 4.59872919e-18+0.j  3.90667868e-18+0.j  1.91358795e-18+0.j
#     -2.87762587e-18+0.j  2.17720558e-18+0.j]
#    [-5.85207827e-18+0.j  9.25523940e-19+0.j -2.43907053e-18+0.j
#      2.57972177e-18+0.j -5.96339269e-18+0.j]
#    [-5.85207827e-18+0.j  9.25523940e-19+0.j -2.43907053e-18+0.j
#      2.57972177e-18+0.j -5.96339269e-18+0.j]
#    [ 4.59872919e-18+0.j  3.90667868e-18+0.j  1.91358795e-18+0.j
#     -2.87762587e-18+0.j  2.17720558e-18+0.j]]
#
#   [[ 7.44090013e-18+0.j -3.23064556e-18+0.j  8.01574128e-18+0.j
#     -6.36896792e-18+0.j -2.41409913e-18+0.j]
#    [ 4.59872919e-18+0.j  2.17720558e-18+0.j -2.87762587e-18+0.j
#      1.91358795e-18+0.j  3.90667868e-18+0.j]
#    [-5.85207827e-18+0.j -5.96339269e-18+0.j  2.57972177e-18+0.j
#     -2.43907053e-18+0.j  9.25523940e-19+0.j]
#    [-5.85207827e-18+0.j -5.96339269e-18+0.j  2.57972177e-18+0.j
#     -2.43907053e-18+0.j  9.25523940e-19+0.j]
#    [ 4.59872919e-18+0.j  2.17720558e-18+0.j -2.87762587e-18+0.j
#      1.91358795e-18+0.j  3.90667868e-18+0.j]]
#
#   [[-1.55527458e-17+0.j  1.28349329e-18+0.j  4.45880010e-18+0.j
#      4.93609256e-18+0.j -6.69643200e-18+0.j]
#    [-9.19745838e-18+0.j -3.81538601e-18+0.j -5.41276824e-19+0.j
#      3.53822580e-18+0.j -1.52592071e-18+0.j]
#    [ 6.46473137e-19+0.j -2.69512577e-19+0.j -1.23638639e-18+0.j
#      7.27505434e-19+0.j -1.40317747e-18+0.j]
#    [ 6.46473137e-19+0.j -2.69512577e-19+0.j -1.23638639e-18+0.j
#      7.27505434e-19+0.j -1.40317747e-18+0.j]
#    [-9.19745838e-18+0.j -3.81538601e-18+0.j -5.41276824e-19+0.j
#      3.53822580e-18+0.j -1.52592071e-18+0.j]]]]
# Calculation using FFT took 0.005505800247192383
# Result using FFT: -0.21678998257410867
# Calculation using pennylane took 0.0013926029205322266
# Result using Pennylane: 0.8861692654023128
